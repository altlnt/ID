# %%
from pylab import *
import os
import pandas as pd

# %%
datapath="./logs/2/csv/DATA"
data=pd.read_pickle(datapath)
# data.to_csv('data_vol_1.csv')

# %%
data
# Out:
#                  t      roll     pitch       yaw  \
# 0         0.000000 -0.051987  0.107089  1.243959
# 1         0.003980 -0.051983  0.107082  1.243980
# 2         0.008161 -0.051975  0.107084  1.244000
# 3         0.012174 -0.051969  0.107089  1.244020
# 4         0.016029 -0.051969  0.107092  1.244039
# ...            ...       ...       ...       ...
# 122828  521.987240 -0.005721  0.040508 -2.288626
# 122829  521.991354 -0.005695  0.040554 -2.288602
# 122830  521.995374 -0.005671  0.040602 -2.288589
# 122831  521.999201 -0.005643  0.040645 -2.288572
# 122832  522.003171 -0.005617  0.040688 -2.288553
#
#                                                         R  manual_x  manual_y  \
# 0       [0.31920987805146006, -0.9475662165507679, -0....       0.0  0.053395
# 1       [0.31919050558354406, -0.9475727315628023, -0....       0.0  0.053395
# 2       [0.31917191000205014, -0.9475790815296342, -0....       0.0  0.053395
# 3       [0.3191524546465999, -0.9475857079038088, -0.0...       0.0  0.053395
# 4       [0.3191351448825753, -0.9475915299124197, -0.0...       0.0  0.053395
# ...                                                   ...       ...       ...
# 122828  [-0.6572116500376084, 0.7533752954835747, -0.0...       0.0  0.050971
# 122829  [-0.6571928610332144, 0.7533902342863896, -0.0...       0.0  0.050971
# 122830  [-0.6571812054772052, 0.7533989431265339, -0.0...       0.0  0.050971
# 122831  [-0.6571672635552275, 0.7534096394655059, -0.0...       0.0  0.050971
# 122832  [-0.6571524897860894, 0.7534211258509016, -0.0...       0.0  0.050971
#
#         manual_z  manual_r    rc_0  ...  accelero_x  accelero_y  accelero_z  \
# 0       0.991474  0.041482  1512.0  ...    1.045927    0.490600   -9.657497
# 1       0.991474  0.041482  1512.0  ...    1.040234    0.506396   -9.679367
# 2       0.991474  0.041482  1512.0  ...    1.040883    0.499718   -9.675551
# 3       0.991474  0.041482  1512.0  ...    1.044473    0.493116   -9.672423
# 4       0.991474  0.041482  1512.0  ...    1.052428    0.510891   -9.663394
# ...          ...       ...     ...  ...         ...         ...         ...
# 122828  0.992215  0.041667  1512.0  ...    0.344140    0.102005   -9.645794
# 122829  0.992196  0.041667  1512.0  ...    0.379255    0.057099   -9.636565
# 122830  0.992178  0.041667  1512.0  ...    0.410885    0.027596   -9.623214
# 122831  0.992161  0.041667  1512.0  ...    0.433129   -0.007630   -9.606755
# 122832  0.992143  0.041667  1512.0  ...    0.457976   -0.015515   -9.641552
#
#         airspeed_mes        baro     mag_x     mag_y     mag_z  \
# 0          -2.006023  152.638870 -0.000616 -0.133297  0.392747
# 1          -2.006023  152.638870 -0.000616 -0.133297  0.392747
# 2          -2.004949  152.710110 -0.007214 -0.132882  0.395252
# 3          -2.003235  152.796795 -0.015221 -0.132379  0.398291
# 4          -2.001588  152.880066 -0.022913 -0.131896  0.401210
# ...              ...         ...       ...       ...       ...
# 122828      1.931510  153.907180 -0.056850  0.128693  0.382372
# 122829      1.928486  153.907180 -0.056850  0.128693  0.382372
# 122830      1.925198  153.997829 -0.056850  0.128693  0.382372
# 122831      1.921822  154.111870 -0.056850  0.128693  0.382372
# 122832      1.918319  154.230173 -0.056850  0.128693  0.382372
#
#         init_timestamp          dt
# 0           15959597.0    0.003980
# 1           15959597.0    0.004181
# 2           15959597.0    0.004013
# 3           15959597.0    0.003855
# 4           15959597.0    0.004059
# ...                ...         ...
# 122828      15959597.0    0.004114
# 122829      15959597.0    0.004020
# 122830      15959597.0    0.003827
# 122831      15959597.0    0.003970
# 122832      15959597.0 -522.003171
#
# [122833 rows x 43 columns]

# %%
data.describe()
# Out:
#                    t           roll          pitch            yaw  \
# count  122833.000000  122833.000000  122833.000000  122833.000000
# mean      260.526423      -0.003577       0.065298      -0.223080
# std       150.589306       0.454386       0.245922       1.880830
# min         0.000000      -1.862639      -1.054382      -3.141536
# 25%       129.638057      -0.256871      -0.033044      -2.183985
# 50%       260.469224      -0.006601       0.063155      -0.205200
# 75%       391.114397       0.199425       0.195546       1.271913
# max       522.003171       1.630055       0.935899       3.141445
#
#             manual_x       manual_y       manual_z       manual_r  \
# count  122833.000000  122833.000000  122833.000000  122833.000000
# mean        0.052232       0.065869       0.512237       0.076629
# std         0.107869       0.235978       0.478316       0.125007
# min        -0.529274      -0.953359       0.000000      -0.483962
# 25%         0.000000       0.042906       0.000000       0.041612
# 50%         0.027346       0.050971       0.492738       0.043513
# 75%         0.099579       0.053509       0.992657       0.094488
# max         0.551510       1.000000       0.999774       1.000000
#
#                 rc_0           rc_1  ...     accelero_x     accelero_y  \
# count  122833.000000  122833.000000  ...  122833.000000  122833.000000
# mean     1486.104963    1556.250174  ...       0.665347      -0.549777
# std        47.156403      52.243792  ...       1.576037       1.854541
# min      1278.013164    1307.065699  ...     -25.419168     -27.835893
# 25%      1463.281727    1543.000000  ...      -0.352649      -1.385443
# 50%      1492.579989    1544.000000  ...       0.282019      -0.741859
# 75%      1511.863712    1564.326331  ...       1.244915       0.481950
# max      1742.900971    1932.986658  ...      11.749139      21.414527
#
#           accelero_z   airspeed_mes           baro          mag_x  \
# count  122833.000000  122833.000000  122833.000000  122833.000000
# mean      -10.425718      14.666986     259.054301      -0.155288
# std         4.689673      10.438174      89.241215       0.138783
# min       -46.983005      -2.053614     149.959998      -0.619062
# 25%       -11.803882       1.788831     154.418362      -0.249179
# 50%        -9.719218      18.644243     280.680524      -0.103936
# 75%        -9.183007      22.847734     339.141288      -0.050387
# max        18.668499      30.843877     424.329836       0.489808
#
#                mag_y          mag_z  init_timestamp             dt
# count  122833.000000  122833.000000        122833.0  122833.000000
# mean        0.038863       0.287727      15959597.0       0.000000
# std         0.194649       0.110908             0.0       1.489476
# min        -0.493628      -0.179251      15959597.0    -522.003171
# 25%        -0.129020       0.225941      15959597.0       0.003948
# 50%         0.103962       0.305288      15959597.0       0.004000
# 75%         0.175921       0.375737      15959597.0       0.004048
# max         0.552113       0.500414      15959597.0       1.187971
#
# [8 rows x 42 columns]

# %% [markdown]
# Exploring the data

# %%
data.keys()
# Out:
# Index(['t', 'roll', 'pitch', 'yaw', 'R', 'manual_x', 'manual_y', 'manual_z',
#        'manual_r', 'rc_0', 'rc_1', 'rc_2', 'rc_3', 'rc_4', 'rc_5', 'rc_6',
#        'rc_7', 'ax_iner', 'ay_iner', 'az_iner', 'vx_iner', 'vy_iner',
#        'vz_iner', 'x_iner', 'y_iner', 'z_iner', 'v_gps_north', 'v_gps_east',
#        'v_gps_down', 'alt', 'gyro_x', 'gyro_y', 'gyro_z', 'accelero_x',
#        'accelero_y', 'accelero_z', 'airspeed_mes', 'baro', 'mag_x', 'mag_y',
#        'mag_z', 'init_timestamp', 'dt'],
#       dtype='object')

# %%
# Plot gyro, mag, baro, gps alt

# %%
figure(figsize=(7,7))

gcf().add_subplot(411)

plot(data.t,data['gyro_x'],label="x",color="blue")
plot(data.t,data['gyro_y'],label="y",color="orange")
plot(data.t,data['gyro_z'],label="z",color="green")
gca().set_ylabel('rad/sec')

grid()
legend()
title('Gyro')

gcf().add_subplot(412)
plot(data.t,data['gyro_x'],label="x",color="blue")
grid()
legend()
gca().set_ylabel('rad/sec')

gcf().add_subplot(413)
plot(data.t,data['gyro_y'],label="y",color="orange")
grid()
legend()
gca().set_ylabel('rad/sec')
gcf().add_subplot(414)
plot(data.t,data['gyro_z'],label="z",color="green")
grid()
legend()
gca().set_xlabel('t (s)')
# Out:
# Text(0.5, 0, 't (s)')

# %%
figure(figsize=(7,7))
plot(data.t,data['mag_x'],label="x")
plot(data.t,data['mag_y'],label="y")
plot(data.t,data['mag_z'],label="z")
grid()
legend()
title('Mag')
gca().set_xlabel('t (s)')
gca().set_ylabel('G')
# Out:
# Text(0, 0.5, 'G')

# %%
figure(figsize=(7,7))
N=sqrt(sum([data[i]**2 for i in data.keys() if 'mag' in i],axis=0))
print([i for i in data.keys() if 'mag' in i])
plot(data.t,N,label="norm")
grid()
legend()
title('Mag norm')
gca().set_xlabel('t (s)')
gca().set_ylabel('G')
# Out:
# ['mag_x', 'mag_y', 'mag_z']
# Text(0, 0.5, 'G')

# %%
figure(figsize=(7,7))
plot(data.t,data['accelero_x'],label="x")
plot(data.t,data['accelero_y'],label="y")
plot(data.t,data['accelero_z'],label="z")
grid()
legend()
title('Acc')
gca().set_xlabel('t (s)')
gca().set_ylabel('m/$s^2$')
# Out:
# Text(0, 0.5, 'm/$s^2$')

# %%
figure(figsize=(7,7))
N=sqrt(sum([data[i]**2 for i in data.keys() if 'accelero' in i],axis=0))
print([i for i in data.keys() if 'accelero' in i])
plot(data.t,N,label="norm")
grid()
legend()
title('Acc norm')
gca().set_xlabel('t (s)')
gca().set_ylabel('m/$s^2$')
# Out:
# ['accelero_x', 'accelero_y', 'accelero_z']
# Text(0, 0.5, 'm/$s^2$')

# %%
figure(figsize=(12,12))
suptitle('Vel')

gcf().add_subplot(311)

plot(data.t,data['vx_iner'],label="vx_ekf")
plot(data.t,data['v_gps_north'],label="vnorth_gps")

grid()
legend()

gcf().add_subplot(312)

plot(data.t,data['vy_iner'],label="vy_ekf")
plot(data.t,data['v_gps_east'],label="veast_gps")

grid()
legend()

gcf().add_subplot(313)

plot(data.t,data['vz_iner'],label="vz_ekf")
plot(data.t,data['v_gps_down'],label="vdown_gps")


grid()
legend()
gca().set_xlabel('t (s)')
gca().set_ylabel('m/s')
# Out:
# Text(0, 0.5, 'm/s')

# %%
figure(figsize=(7,7))
suptitle('Alt')

gcf().add_subplot(111)

plot(data.t,data['baro']-data['baro'].values[0],label="baro")
plot(data.t,0.001*(data['alt']-data['alt'].values[0]),label="gps")
plot(data.t,-cumsum(data.dt*data['v_gps_down']),label="integrated gps vdown")
grid()
legend()

# %%
figure(figsize=(7,7))
suptitle('Airspeed')

gcf().add_subplot(111)

plot(data.t,data['airspeed_mes'],label="measured airspeed")

grid()
legend()

# %%
data.keys()
# Out:
# Index(['t', 'roll', 'pitch', 'yaw', 'R', 'manual_x', 'manual_y', 'manual_z',
#        'manual_r', 'rc_0', 'rc_1', 'rc_2', 'rc_3', 'rc_4', 'rc_5', 'rc_6',
#        'rc_7', 'ax_iner', 'ay_iner', 'az_iner', 'vx_iner', 'vy_iner',
#        'vz_iner', 'x_iner', 'y_iner', 'z_iner', 'v_gps_north', 'v_gps_east',
#        'v_gps_down', 'alt', 'gyro_x', 'gyro_y', 'gyro_z', 'accelero_x',
#        'accelero_y', 'accelero_z', 'airspeed_mes', 'baro', 'mag_x', 'mag_y',
#        'mag_z', 'init_timestamp', 'dt'],
#       dtype='object')

# %%
figure(figsize=(11,11))
suptitle('Manual')

gcf().add_subplot(111)

[plot(data.t,data[i],label=i) for i in data.keys() if "manual" in i]

grid()
legend()

# %%
figure(figsize=(11,11))
suptitle('RC')

gcf().add_subplot(111)

[plot(data.t,data[i],label=i) for i in data.keys() if "rc_" in i]

grid()
legend()

# %%
# figure(figsize=(15,15))
# suptitle('Manual')

# gcf().add_subplot(421)
# scatter(data.manual_z,sqrt(sum([data[i]**2 for i in data.keys() if 'accel' in i],axis=0)),label="acc norm vs thrust ")
# grid()
# legend()

# gcf().add_subplot(423)
# scatter(data.manual_z,data.accelero_x,label="accx vs thrust")
# grid()
# legend()

# gcf().add_subplot(425)
# scatter(data.manual_z,data.accelero_y,label="accy vs thrust")
# grid()
# legend()

# gcf().add_subplot(427)
# scatter(data.manual_z,data.accelero_z,label="accz vs thrust")
# grid()
# legend()

# gcf().add_subplot(422)
# scatter(data.manual_z,sqrt(sum([data[i]**2 for i in data.keys() if 'mag' in i],axis=0)),label="mag norm vs thrust")
# grid()
# legend()

# gcf().add_subplot(424)
# scatter(data.manual_z,data.mag_x,label="magx vs thrust")
# grid()
# legend()


# gcf().add_subplot(426)
# scatter(data.manual_z,data.mag_y,label="magy vs thrust")
# grid()
# legend()

# gcf().add_subplot(428)
# scatter(data.manual_z,data.mag_y,label="magz vs thrust")
# grid()
# legend()

# %%
figure(figsize=(15,15))
suptitle('Manual')

gcf().add_subplot(421)
scatter(data.rc_5,sqrt(sum([data[i]**2 for i in data.keys() if 'accel' in i],axis=0)),label="acc norm vs thrust ",alpha=0.1)
grid()
legend()

gcf().add_subplot(423)
scatter(data.rc_5,data.accelero_x,label="accx vs thrust",alpha=0.1)
grid()
legend()

gcf().add_subplot(425)
scatter(data.rc_5,data.accelero_y,label="accy vs thrust",alpha=0.1)
grid()
legend()

gcf().add_subplot(427)
scatter(data.rc_5,data.accelero_z,label="accz vs thrust",alpha=0.1)
grid()
legend()

gcf().add_subplot(422)
scatter(data.rc_5,sqrt(sum([data[i]**2 for i in data.keys() if 'mag' in i],axis=0)),label="mag norm vs thrust",alpha=0.1)
grid()
legend()

gcf().add_subplot(424)
scatter(data.rc_5,data.mag_x,label="magx vs thrust",alpha=0.1)
grid()
legend()


gcf().add_subplot(426)
scatter(data.rc_5,data.mag_y,label="magy vs thrust",alpha=0.1)
grid()
legend()

gcf().add_subplot(428)
scatter(data.rc_5,data.mag_y,label="magz vs thrust",alpha=0.1)
grid()
legend()
